# %%
from sklearn import datasets
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cicrles = datasets.make_circles()

# %%
print("features {}".format(cicrles[0][:10]))
print("target {}".format(cicrles[1][:10]))
# Out:
# features [[ 6.37423990e-01  7.70513243e-01]
#  [-7.93691761e-01  1.00266587e-01]
#  [-5.02324156e-02 -7.98421383e-01]
#  [ 1.87381315e-01  9.82287251e-01]
#  [ 7.93691761e-01 -1.00266587e-01]
#  [-9.29776486e-01  3.68124553e-01]
#  [-3.40623433e-01  7.23861642e-01]
#  [ 8.09016994e-01 -5.87785252e-01]
#  [-8.76306680e-01  4.81753674e-01]
#  [-1.00000000e+00 -3.21624530e-16]]
# target [0 1 1 0 1 0 1 0 0 0]

# %%
from matplotlib.colors import ListedColormap

# %%
colors = ListedColormap(['red', 'yellow'])

pyplot.figure(figsize(8,8))
pyplot.scatter(list(map(lambda x: x[0], cicrles[0])), \
              list(map(lambda x: x[1], cicrles[0])), \
              c=cicrles[1], cmap=colors);
